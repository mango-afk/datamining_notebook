# %%
import pandas as pd

df = pd.read_cscv('veteran.csv')

print(df.info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4d73181f1347> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_cscv('veteran.csv')
#       4
#       5 print(df.info())
#
# AttributeError: module 'pandas' has no attribute 'read_cscv'

# %%
import pandas as pd

df = pd.read_csv('veteran.csv')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9686 entries, 0 to 9685
# Data columns (total 28 columns):
# TargetB             9686 non-null int64
# ID                  9686 non-null int64
# TargetD             4843 non-null float64
# GiftCnt36           9686 non-null int64
# GiftCntAll          9686 non-null int64
# GiftCntCard36       9686 non-null int64
# GiftCntCardAll      9686 non-null int64
# GiftAvgLast         9686 non-null float64
# GiftAvg36           9686 non-null float64
# GiftAvgAll          9686 non-null float64
# GiftAvgCard36       7906 non-null float64
# GiftTimeLast        9686 non-null int64
# GiftTimeFirst       9686 non-null int64
# PromCnt12           9686 non-null int64
# PromCnt36           9686 non-null int64
# PromCntAll          9686 non-null int64
# PromCntCard12       9686 non-null int64
# PromCntCard36       9686 non-null int64
# PromCntCardAll      9686 non-null int64
# StatusCat96NK       9686 non-null object
# ...

# %%
df['DemCluster'] = df['DemCluster]'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DemCluster]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-caea1c681bd9> in <module>
# ...

# %%
df['DemCluster'] = df['DemCluster'].astype(str)

# %%
df['DemHomeOwner'].value_counts()
# Out:
# H    5377
# U    4309
# Name: DemHomeOwner, dtype: int64

# %%
dem_home_owner_map = {'U':0, 'H': 1}
df['DemHomeOwner'] = df['DemHomeOwner'].map(dem_home_owner_map)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9686 entries, 0 to 9685
# Data columns (total 28 columns):
# TargetB             9686 non-null int64
# ID                  9686 non-null int64
# TargetD             4843 non-null float64
# GiftCnt36           9686 non-null int64
# GiftCntAll          9686 non-null int64
# GiftCntCard36       9686 non-null int64
# GiftCntCardAll      9686 non-null int64
# GiftAvgLast         9686 non-null float64
# GiftAvg36           9686 non-null float64
# GiftAvgAll          9686 non-null float64
# GiftAvgCard36       7906 non-null float64
# GiftTimeLast        9686 non-null int64
# GiftTimeFirst       9686 non-null int64
# PromCnt12           9686 non-null int64
# PromCnt36           9686 non-null int64
# PromCntAll          9686 non-null int64
# PromCntCard12       9686 non-null int64
# PromCntCard36       9686 non-null int64
# PromCntCardAll      9686 non-null int64
# StatusCat96NK       9686 non-null object
# ...

# %%
print(df['DemAge'].describe())
# Out:
# count    7279.000000
# mean       59.150845
# std        16.516400
# min         0.000000
# 25%        47.000000
# 50%        60.000000
# 75%        73.000000
# max        87.000000
# Name: DemAge, dtype: float64

# %%
print(df['DemAge'].unique())
# Out:
# [nan 67. 53. 47. 58. 39. 50. 45. 80. 61. 76. 41. 75. 59. 51. 31. 54. 70.
#  42. 65. 81. 38. 56. 69. 52. 33. 73. 71. 29. 60. 83. 43. 35. 77. 44. 72.
#  64. 34. 55. 37. 57. 46. 49. 32. 66. 87. 40. 79. 25. 63. 62. 48. 68. 86.
#  23. 27. 74. 78. 85. 26.  7. 36. 82. 24. 17. 30. 84. 21. 28. 22. 19. 16.
#  14.  6.  0.  2. 20. 18. 15.  4.]

# %%
pinrt(df['DemAge'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2a3f99aa586c> in <module>
# ----> 1 pinrt(df['DemAge'].value_counts())
#
# NameError: name 'pinrt' is not defined

# %%
print(df['DemAge'].value_counts())
# Out:
# 73.0    216
# 67.0    215
# 75.0    203
# 49.0    201
# 57.0    187
# 77.0    183
# 55.0    182
# 65.0    181
# 47.0    179
# 69.0    178
# 71.0    173
# 51.0    167
# 79.0    165
# 45.0    164
# 74.0    162
# 53.0    152
# 59.0    150
# 76.0    139
# 43.0    138
# 63.0    138
# 81.0    136
# 61.0    136
# 50.0    131
# 37.0    125
# 41.0    124
# 78.0    123
# 80.0    123
# 72.0    122
# 70.0    116
# 68.0    116
#        ...
# 84.0     70
# 27.0     69
# 86.0     68
# 33.0     65
# 31.0     59
# 36.0     57
# 38.0     53
# 17.0     46
# 34.0     42
# 29.0     33
# 7.0      32
# 32.0     31
# 30.0     24
# 26.0     19
# 28.0     19
# 25.0     17
# 23.0     12
# 22.0      7
# 24.0      6
# 16.0      5
# 21.0      5
# 19.0      4
# 6.0       3
# 14.0      1
# 0.0       1
# 2.0       1
# 20.0      1
# 4.0       1
# 18.0      1
# 15.0      1
# Name: DemAge, Length: 79, dtype: int64

# %%
print(df['DemAge'].value_counts(bins=10))
# Out:
# (69.6, 78.3]     1437
# (60.9, 69.6]     1250
# (43.5, 52.2]     1223
# (52.2, 60.9]     1043
# (78.3, 87.0]      932
# (34.8, 43.5]      889
# (26.1, 34.8]      342
# (17.4, 26.1]       72
# (8.7, 17.4]        53
# (-0.088, 8.7]      38
# Name: DemAge, dtype: int64

# %%
print(df['GiftAvgCard36'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       17.00
# 1         NaN
# 2        5.00
# 3        8.67
# 4       20.00
# 5        8.00
# 6       20.00
# 7         NaN
# 8         NaN
# 9       20.00
# 10       6.00
# 11       5.00
# 12        NaN
# 13        NaN
# 14       5.00
# 15       5.33
# 16      15.00
# 17       5.67
# 18      50.00
# 19       5.67
# 20      36.00
# 21        NaN
# 22       7.50
# 23      15.00
# 24        NaN
# 25      20.00
# 26      20.00
# 27      10.00
# 28      10.33
# 29       9.67
#         ...
# 9656      NaN
# 9657    15.00
# 9658     7.00
# 9659     8.75
# 9660     7.50
# 9661    10.00
# 9662    12.00
# 9663      NaN
# 9664      NaN
# 9665    10.67
# 9666    22.50
# 9667    22.40
# 9668    15.00
# 9669    20.00
# 9670    16.00
# 9671      NaN
# 9672    20.00
# 9673    25.00
# 9674    25.00
# 9675    20.00
# 9676    15.50
# 9677      NaN
# 9678    20.00
# 9679      NaN
# 9680    20.00
# 9681    15.00
# 9682    10.00
# 9683     8.80
# ...

# %%
print(df['GiftAvgCard36'].unique())
# Out:
# [ 17.      nan   5.     8.67  20.     8.     6.     5.33  15.     5.67
#   50.    36.     7.5   10.    10.33   9.67  16.5   16.33   3.5    6.5
#   12.    19.    25.    16.     6.67  13.33  11.     9.     9.5   12.5
#    7.67  14.     4.5   17.5    5.14   7.75  15.5    3.    10.75   6.75
#   18.33   7.    28.33  30.    11.33  13.     9.8   21.    18.     8.33
#   16.6   23.    11.5    4.75   6.29  14.5    9.33  12.33   8.2   13.67
#   10.2   26.67  42.     8.5   22.5    3.75  11.67 125.    33.75  62.
#    4.33  10.67   9.4  100.     5.5    6.43   6.25  18.67  14.33   5.6
#    6.33  26.    20.5    2.86   3.8   22.6   31.     4.2   19.17  35.
#    4.    23.67  42.5   21.25  13.5    7.33   7.4   10.25  22.33  10.57
#    7.25  10.6   44.5   11.2   32.5   10.5   11.25   3.63   9.63   4.25
#    4.83   5.8    4.67  22.    45.    17.67  19.5   20.2   18.75   3.86
#    7.71  15.67   4.57   3.38   6.14   3.67  16.67  20.33  18.5   38.65
# ...

# %%
print(df['GiftAvgCard36'].describe())
# Out:
# count    7906.000000
# mean       14.224431
# std        10.022710
# min         1.330000
# 25%         8.670000
# 50%        12.500000
# 75%        18.000000
# max       260.000000
# Name: GiftAvgCard36, dtype: float64

# %%
print(df['GiftAvgCard36'].value_counts(bins=10))
# Out:
# (1.07, 27.197]        7556
# (27.197, 53.064]       301
# (53.064, 78.931]        23
# (78.931, 104.798]       20
# (104.798, 130.665]       2
# (234.133, 260.0]         1
# (182.399, 208.266]       1
# (156.532, 182.399]       1
# (130.665, 156.532]       1
# (208.266, 234.133]       0
# Name: GiftAvgCard36, dtype: int64

# %%
print(df['GiftAvgCard36'].value_counts(bins=20))
# Out:
# (1.07, 14.264]        4539
# (14.264, 27.197]      3017
# (27.197, 40.13]        216
# (40.13, 53.064]         85
# (91.864, 104.798]       14
# (53.064, 65.998]        13
# (65.998, 78.931]        10
# (78.931, 91.864]         6
# (117.732, 130.665]       2
# (143.599, 156.532]       1
# (156.532, 169.466]       1
# (195.332, 208.266]       1
# (247.067, 260.0]         1
# (130.665, 143.599]       0
# (234.133, 247.067]       0
# (104.798, 117.732]       0
# (169.466, 182.399]       0
# (182.399, 195.332]       0
# (208.266, 221.2]         0
# (221.2, 234.133]         0
# Name: GiftAvgCard36, dtype: int64

# %%
import numpy as np
df2 = df.select_dtypes(include=[np.number])

# %%
df2.mean()
# Out:
# TargetB                  0.500000
# ID                   97975.474086
# TargetD                 15.624344
# GiftCnt36                3.205451
# GiftCntAll              10.507640
# GiftCntCard36            1.856597
# GiftCntCardAll           5.582490
# GiftAvgLast             16.017739
# GiftAvg36               14.876203
# GiftAvgAll              12.489325
# GiftAvgCard36           14.224431
# GiftTimeLast            18.002168
# GiftTimeFirst           71.100351
# PromCnt12               12.988850
# PromCnt36               29.348235
# PromCntAll              48.483481
# PromCntCard12            5.392009
# PromCntCard36           11.954677
# PromCntCardAll          19.007124
# StatusCatStarAll         0.540574
# DemAge                  59.150845
# DemHomeOwner             0.555131
# DemMedHomeValue     110986.299814
# DemPctVeterans          30.604274
# DemMedIncome         40491.444249
# dtype: float64

# %%
df2.median()
# Out:
# TargetB                 0.50
# ID                  99106.00
# TargetD                13.00
# GiftCnt36               3.00
# GiftCntAll              8.00
# GiftCntCard36           1.00
# GiftCntCardAll          4.00
# GiftAvgLast            15.00
# GiftAvg36              13.50
# GiftAvgAll             10.71
# GiftAvgCard36          12.50
# GiftTimeLast           18.00
# GiftTimeFirst          68.00
# PromCnt12              12.00
# PromCnt36              31.00
# PromCntAll             48.00
# PromCntCard12           6.00
# PromCntCard36          13.00
# PromCntCardAll         19.00
# StatusCatStarAll        1.00
# DemAge                 60.00
# DemHomeOwner            1.00
# DemMedHomeValue     76900.00
# DemPctVeterans         31.00
# DemMedIncome        43100.00
# dtype: float64

# %%
df2.mode()[0:1]
# Out:
#    TargetB  ID  TargetD  GiftCnt36  GiftCntAll  GiftCntCard36  GiftCntCardAll  \
# 0      0.0  12     10.0        2.0         1.0            1.0             1.0
#
#    GiftAvgLast  GiftAvg36  GiftAvgAll  ...  PromCntAll  PromCntCard12  \
# 0         15.0       15.0        15.0  ...        13.0            6.0
#
#    PromCntCard36  PromCntCardAll  StatusCatStarAll  DemAge  DemHomeOwner  \
# 0           17.0            15.0               1.0    73.0           1.0
#
#    DemMedHomeValue  DemPctVeterans  DemMedIncome
# 0              0.0            32.0           0.0
#
# [1 rows x 25 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ax = sns.boxplot(df['DemMedIncome'])
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

dg = sns.distplot(df['DemMedIncome'])
plt.show()

# %%
dropna(df['DemAge'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3e8e0df18b12> in <module>
# ----> 1 dropna(df['DemAge'])
#
# NameError: name 'dropna' is not defined

# %%
pd.dropna(df['DemAge'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-a91b932b57fc> in <module>
# ----> 1 pd.dropna(df['DemAge'])
#
# AttributeError: module 'pandas' has no attribute 'dropna'

# %%
df.dropna()
# Out:
#       TargetB      ID  TargetD  GiftCnt36  GiftCntAll  GiftCntCard36  \
# 5           1  112632     11.0          3          11              2
# 14          1  164513     50.0          2           2              1
# 20          1    6789     10.0          1          20              1
# 23          1  127346     10.0          1           1              1
# 27          1    5532     15.0          2          14              2
# 30          1  190726     10.0          4          14              2
# 36          1   34174     12.0          2          12              1
# 37          1   15038     25.0          1          10              1
# 40          1   15046     10.0          3          22              3
# 41          1   15066     10.0          4          24              2
# 47          1   15332     10.0          2          13              1
# 50          1   15350     15.0          2           2              1
# 51          1   15384     15.0          2           2              1
# ...

# %%
da = sns.distplot(df.['DemAge'])
plt.show()
# Out:
#   File "<ipython-input-29-7907f158c256>", line 1
#     da = sns.distplot(df.['DemAge'])
#                          ^
# SyntaxError: invalid syntax

# %%
da = sns.distplot(df['DemAge'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e5d1c45020c3> in <module>
# ----> 1 da = sns.distplot(df['DemAge'])
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
dg = sns.countplot(data=df, x='DemGender')
plt.show()

# %%
dfr = df.dropna()

# %%
print(dfr.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3101 entries, 5 to 9683
# Data columns (total 28 columns):
# TargetB             3101 non-null int64
# ID                  3101 non-null int64
# TargetD             3101 non-null float64
# GiftCnt36           3101 non-null int64
# GiftCntAll          3101 non-null int64
# GiftCntCard36       3101 non-null int64
# GiftCntCardAll      3101 non-null int64
# GiftAvgLast         3101 non-null float64
# GiftAvg36           3101 non-null float64
# GiftAvgAll          3101 non-null float64
# GiftAvgCard36       3101 non-null float64
# GiftTimeLast        3101 non-null int64
# GiftTimeFirst       3101 non-null int64
# PromCnt12           3101 non-null int64
# PromCnt36           3101 non-null int64
# PromCntAll          3101 non-null int64
# PromCntCard12       3101 non-null int64
# PromCntCard36       3101 non-null int64
# PromCntCardAll      3101 non-null int64
# StatusCat96NK       3101 non-null object
# ...

# %%
dg = sns.distplot(dfr['DemAge'])
plt.show()

# %%
dg = sns.distplot(dfr['DemMedIncome'])
plt.show()

# %%
dg = sns.distplot(df['DemAge'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8dbb8b675de9> in <module>
# ----> 1 dg = sns.distplot(df['DemAge'])
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
print(df.groupby(['TargetB'])['DemAge'].mean())
# Out:
# TargetB
# 0    58.304444
# 1    59.979070
# Name: DemAge, dtype: float64

# %%
print("Raw count of geners of lapsing and non-lapsing donors")
print(df.groupby(['TargetB'])['DemGender'].value_counts())

print("------------------")

print("Normalised count (percentage) of geners of lapsing and non-lapsing donors")
print(df.groupby(['TargetB'])['DemGender'].value_counts(normalize=True))
# Out:
# Raw count of geners of lapsing and non-lapsing donors
# TargetB  DemGender
# 0        F            2614
#          M            1963
#          U             266
# 1        F            2609
#          M            1962
#          U             272
# Name: DemGender, dtype: int64
# ------------------
# Normalised count (percentage) of geners of lapsing and non-lapsing donors
# TargetB  DemGender
# 0        F            0.539748
#          M            0.405327
#          U            0.054925
# 1        F            0.538716
#          M            0.405121
#          U            0.056164
# Name: DemGender, dtype: float64

# %%
import matplotlib.pyplot as plt2
plt2.scatter(df['GiftAvg36'], df['GiftAvgCard36'])
plt2.title('Correlation')
plt2.xlabel('Gift Average 36')
plt2.ylabel('Gift Average Card 36')
plt2.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

corr = df2.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df2.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df2.columns)
ax.set_yticklabels(df2.columns)
plt.show()
